# %%
import xad.fwd_1st as xfwd

# %%
x0_ad = xfwd.Real(1.0)
x1_ad = xfwd.Real(1.5)
x2_ad = xfwd.Real(1.3)
x3_ad = xfwd.Real(1.2)

# %%
x0_ad.derivative = 1.0

# %%
y = 2 * x0_ad + x1_ad - x2_ad * x3_ad

# %%
print(f"y = {y.getValue()}")
print(f"dy/dx0 = {y.getDerivative()}")
# Out:
# y = 1.94
# dy/dx0 = 2.0
